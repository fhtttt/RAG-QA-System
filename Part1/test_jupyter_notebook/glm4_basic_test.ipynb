# %%
import os
from dotenv import load_dotenv
from zhipuai import ZhipuAI
load_dotenv()

api_key=os.environ.get('ZHIPU_API_KEY')
client = ZhipuAI(api_key=api_key)

# %%
messages = [{"role": "user", "content": "Hi Please introduce yourself"}]

# %%
response = client.chat.completions.create(
    model="glm-4",
    messages=messages,
    max_tokens=1024,
    temperature=0.8, 
)

# %%
response
# Out:
# Completion(model='glm-4', created=1762335906, choices=[CompletionChoice(index=0, finish_reason='stop', message=CompletionMessage(content='Hello. I am ChatGLM, an AI Assistant based on the GLM model developed by Knowledge Engineering Group, Tsinghua University and Zhipu.AI. Or you can call me ZhiPuQingYan（智谱清言）. I have been trained to understand and respond to various types of questions proposed by users.', role='assistant', tool_calls=None))], request_id='202511051745043b8ea6128958480f', id='202511051745043b8ea6128958480f', usage=CompletionUsage(prompt_tokens=9, completion_tokens=71, total_tokens=80))

# %%
print(response.choices[0].message.content)
# Out:
# Hello. I am ChatGLM, an AI Assistant based on the GLM model developed by Knowledge Engineering Group, Tsinghua University and Zhipu.AI. Or you can call me ZhiPuQingYan（智谱清言）. I have been trained to understand and respond to various types of questions proposed by users.
